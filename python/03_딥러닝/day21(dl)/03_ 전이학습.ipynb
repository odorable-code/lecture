# %%
# 전이 학습 모델 로드
from tensorflow.keras.applications import mobilenet_v2

mobile = mobilenet_v2.MobileNetV2(weights='imagenet', include_top=True)
# Out:
# ...
# 14536120/14536120 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
# 테스트할 이미지 준비
import requests
from tensorflow.keras.preprocessing import image
from io import BytesIO
url = 'https://d2zp5xs5cp8zlg.cloudfront.net/image-89949-800.jpg'
resp = requests.get(url)
img = image.load_img(BytesIO(resp.content), target_size=(224, 224))

# %%
# 이미지 전처리 => 입력 형태 맞추기, 이미지를 배열로
X = image.img_to_array(img)
X
# Out:
# array([[[164., 164., 166.],
#         [165., 165., 167.],
#         [165., 165., 167.],
#         ...,
#         [160., 160., 162.],
#         [160., 160., 162.],
#         [160., 160., 162.]],
#
#        [[164., 164., 166.],
#         [165., 165., 167.],
#         [165., 165., 167.],
#         ...,
#         [160., 160., 162.],
#         [160., 160., 162.],
#         [160., 160., 162.]],
#
#        [[164., 164., 166.],
#         [165., 165., 167.],
#         [165., 165., 167.],
#         ...,
#         [160., 160., 162.],
#         [160., 160., 162.],
#         [160., 160., 162.]],
#
#        ...,
#
#        [[144., 144., 144.],
#         [144., 144., 144.],
#         [144., 144., 144.],
#         ...,
#         [144., 144., 144.],
#         [144., 144., 144.],
#         [144., 144., 144.]],
#
#        [[150., 150., 150.],
#         [150., 150., 150.],
#         [150., 150., 150.],
#         ...,
#         [149., 149., 149.],
#         [149., 149., 149.],
# ...

# %%
# MobileNet v2 전용 전처리
