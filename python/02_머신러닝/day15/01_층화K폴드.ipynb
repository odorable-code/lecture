# %%
# 층화 K폴드 교차 검증 예제: 성능 평가
from sklearn.datasets import load_iris

# %%
dataset = load_iris()
X, y = dataset['data'], dataset['target']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
import numpy as np
